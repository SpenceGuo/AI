# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
x = range(2, 26, 2)

# %%
x
# Out:
# range(2, 26, 2)

# %%
y = [15,13,14.5,17,20,25,26,26,24,22,18,15]

# %%
# 设置图片大小
plt.figure(figsize=(20,10),dpi=40)

plt.plot(x,y)

# 设置x轴刻度  (y轴操作类似，设置plt.yticks)
# plt.xticks(x)
# plt.xticks(range(2, 26))
_xts = [m/2 for m in range(4,52)]
plt.xticks(_xts[::3])

# 保存图片
plt.savefig('test.png')

# 显示图片
plt.show()

# %%
y1 = [m for m in x]
plt.plot(x,y1)
plt.show()
